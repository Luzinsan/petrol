# %%
import pandas as pd
pd.options.display.max_rows = 999

# %%
df = pd.read_excel('../data/raw/2023/Режимный_лист_МУИС_2023.xlsx', sheet_name='Март 2023')

# %%
df.iloc[90:110,[0, 56, 31]]
# Out:
#     Режимный лист МУИС-2500 Воронцовского месторождения          Unnamed: 56  \
# 90                                            20:00:00                   NaN
# 91                                            22:00:00                   NaN
# 92                                            00:00:00                   NaN
# 93                                                 NaN                   NaN
# 94                                      Дата/Время мск   Добыча воды за 2 ч
# 95                                                 NaN                   NaN
# 96                                                 NaN                    м3
# 97                                                 NaN              2.459747
# 98                                 2023-03-01 00:00:00              2.425342
# 99                                            02:00:00              2.365038
# 100                                           04:00:00              2.421466
# ...
